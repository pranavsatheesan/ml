# %% [markdown]
# # Students Do: Preventing credit card defaults with neural networks
#
# In this activity, you will train a neural network model to predict whether a credit card holder will default in the next month.
#
# The dataset provided contains `30,000` anonymous records of credit default status with `23` features columns and one binary target column entitled _DEFAULT_, where `1` represents a defaulted credit card.
#
# The `23` features include demographic info (age, gender, marital status, etc.), credit limit, past payment details, and other relevant information.
#
# You are tasked to create a neural network model to predict if a credit card holder will default.

# %%
# Initial imports
from path import Path
import pandas as pd
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %matplotlib inline

# %% [markdown]
# ## Instructions
#
# 1. Load the data in a Pandas DataFrame.

# %%
# Read in data
file_path = Path(r'D:\data\neural\cc_default.csv')
df = pd.read_csv(file_path)

df.head()
# Out:
#    LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0      20000    2          2         1   24      2      2     -1     -1
# 1     120000    2          2         2   26     -1      2      0      0
# 2      90000    2          2         2   34      0      0      0      0
# 3      50000    2          2         1   37      0      0      0      0
# 4      50000    1          2         1   57     -1      0     -1      0
#
#    PAY_5  ...           "BILL_AMT4"  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  \
# 0     -2  ...                     0          0          0         0       689
# 1      0  ...                  3272       3455       3261         0      1000
# 2      0  ...                 14331      14948      15549      1518      1500
# 3      0  ...                 28314      28959      29547      2000      2019
# 4      0  ...                 20940      19146      19131      2000     36681
#
#    PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6  DEFAULT
# 0         0         0         0         0        1
# 1      1000      1000         0      2000        1
# 2      1000      1000      1000      5000        0
# 3      1200      1100      1069      1000        0
# 4     10000      9000       689       679        0
#
# [5 rows x 24 columns]

# %% [markdown]
# 2. Define the features set `X` by including all the columns of the DataFrame except the `DEFAULT` column.

# %%
# Define features data

features_df = df.drop(columns = ["DEFAULT"])
features_df.head()
# Out:
#    LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0      20000    2          2         1   24      2      2     -1     -1
# 1     120000    2          2         2   26     -1      2      0      0
# 2      90000    2          2         2   34      0      0      0      0
# 3      50000    2          2         1   37      0      0      0      0
# 4      50000    1          2         1   57     -1      0     -1      0
#
#    PAY_5  ...  BILL_AMT3           "BILL_AMT4"  BILL_AMT5  BILL_AMT6  \
# 0     -2  ...        689                     0          0          0
# 1      0  ...       2682                  3272       3455       3261
# 2      0  ...      13559                 14331      14948      15549
# 3      0  ...      49291                 28314      28959      29547
# 4      0  ...      35835                 20940      19146      19131
#
#    PAY_AMT1  PAY_AMT2  PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6
# 0         0       689         0         0         0         0
# 1         0      1000      1000      1000         0      2000
# 2      1518      1500      1000      1000      1000      5000
# 3      2000      2019      1200      1100      1069      1000
# 4      2000     36681     10000      9000       689       679
#
# [5 rows x 23 columns]

# %% [markdown]
# 3. Create the target vector `y` by assigning the values of the `DEFAULT` column of the DataFrame.

# %%
# Define target data
output_df = df["DEFAULT"].to_frame()
output_df.head()
# Out:
#    DEFAULT
# 0        1
# 1        1
# 2        0
# 3        0
# 4        0

# %% [markdown]
# 4. Create the training an testing sets using the `train_test_split` function from `sklearn`.

# %%
# Create training and testing datasets
features_df_train, features_df_test, output_df_train, output_df_test = train_test_split(
    features_df, output_df, random_state=78
)

# %% [markdown]
# 5. Scale the features data using the `StandardScaler` from `sklearn`.

# %%
# Create the scaler instance

features_df_scaler = StandardScaler()

# %%
# Fit the scaler

features_df_scaler.fit(features_df_train)
# Out:
# StandardScaler()

# %%
# Scale the features data
features_df_train_scaled = features_df_scaler.transform(features_df_train)
features_df_test_scaled = features_df_scaler.transform(features_df_test)

# %% [markdown]
# 6. Create a neural network model with `23` inputs, one hidden layer with `69` units, and an output layer with a single output. Use the `relu` activation function for the first layer and `sigmoid` for the second layer.

# %%
# Define the model
number_inputs = 23
number_hidden_nodes = 69

nn = Sequential()

nn.add(Dense(units=number_hidden_nodes, activation="relu", input_dim=number_inputs))

number_classes = 1

nn.add(Dense(units=number_classes, activation="sigmoid"))

nn.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_2 (Dense)              (None, 69)                1656
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 70
# =================================================================
# Total params: 1,726
# Trainable params: 1,726
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# 7. Compile the neural network model using the `binary_crossentropy` loss function, the `adam` optimizer, and `accuracy` as additional metric.

# %%
# Compile model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %% [markdown]
# 8. Fit the model with `100` epochs.

# %%
# Fit the model
model_cc = nn.fit(features_df_train_scaled, output_df_train, epochs=100)
# Out:
# Epoch 1/100
# 704/704 [==============================] - 1s 970us/step - loss: 0.5415 - accuracy: 0.7509
# Epoch 2/100
# 704/704 [==============================] - 1s 859us/step - loss: 0.4494 - accuracy: 0.8155
# Epoch 3/100
# 704/704 [==============================] - 1s 922us/step - loss: 0.4514 - accuracy: 0.8114
# Epoch 4/100
# 704/704 [==============================] - 1s 983us/step - loss: 0.4477 - accuracy: 0.8108
# Epoch 5/100
# 704/704 [==============================] - 1s 896us/step - loss: 0.4431 - accuracy: 0.8121
# Epoch 6/100
# 704/704 [==============================] - 1s 919us/step - loss: 0.4373 - accuracy: 0.8169
# Epoch 7/100
# 704/704 [==============================] - 1s 891us/step - loss: 0.4324 - accuracy: 0.8208
# Epoch 8/100
# 704/704 [==============================] - 1s 988us/step - loss: 0.4317 - accuracy: 0.8225
# Epoch 9/100
# 704/704 [==============================] - 1s 969us/step - loss: 0.4380 - accuracy: 0.8162
# Epoch 10/100
# 704/704 [==============================] - 1s 899us/step - loss: 0.4291 - accuracy: 0.8215
# Epoch 11/100
# 704/704 [==============================] - 1s 929us/step - loss: 0.4314 - accuracy: 0.8202
# Epoch 12/100
# 704/704 [==============================] - 1s 1ms/step - loss: 0.4339 - accuracy: 0.8166
# Epoch 13/100
# 704/704 [==============================] - 1s 929us/step - loss: 0.4183 - accuracy: 0.8235
# Epoch 14/100
# 704/704 [==============================] - 1s 902us/step - loss: 0.4246 - accuracy: 0.8229
# Epoch 15/100
# 704/704 [==============================] - 1s 962us/step - loss: 0.4252 - accuracy: 0.8232
# Epoch 16/100
# 704/704 [==============================] - 1s 1ms/step - loss: 0.4263 - accuracy: 0.8206
# Epoch 17/100
# 704/704 [==============================] - 1s 1ms/step - loss: 0.
100
# 704/704 [==============================] - 1s 1ms/step - loss: 0.4084 - accuracy: 0.8256
# Epoch 85/100
# 704/704 [==============================] - 1s 885us/step - loss: 0.4107 - accuracy: 0.8264
# Epoch 86/100
# 704/704 [==============================] - 1s 954us/step - loss: 0.4070 - accuracy: 0.8277
# Epoch 87/100
# 704/704 [==============================] - 1s 950us/step - loss: 0.4095 - accuracy: 0.8245
# Epoch 88/100
# 704/704 [==============================] - 1s 953us/step - loss: 0.4012 - accuracy: 0.8322
# Epoch 89/100
# 704/704 [==============================] - 1s 861us/step - loss: 0.4071 - accuracy: 0.8267
# Epoch 90/100
# 704/704 [==============================] - 1s 862us/step - loss: 0.4019 - accuracy: 0.8273
# Epoch 91/100
# 704/704 [==============================] - 1s 930us/step - loss: 0.4039 - accuracy: 0.8303
# Epoch 92/100
# 704/704 [==============================] - 1s 955us/step - loss: 0.4017 - accuracy: 0.8302
# Epoch 93/100
# 704/704 [==============================] - 1s 992us/step - loss: 0.4038 - accuracy: 0.8259
# Epoch 94/100
# 704/704 [==============================] - 1s 861us/step - loss: 0.4039 - accuracy: 0.8286
# Epoch 95/100
# 704/704 [==============================] - 1s 882us/step - loss: 0.4013 - accuracy: 0.8298
# Epoch 96/100
# 704/704 [==============================] - 1s 1ms/step - loss: 0.3995 - accuracy: 0.8287
# Epoch 97/100
# 704/704 [==============================] - 1s 857us/step - loss: 0.4099 - accuracy: 0.8216
# Epoch 98/100
# 704/704 [==============================] - 1s 904us/step - loss: 0.4027 - accuracy: 0.8298
# Epoch 99/100
# 704/704 [==============================] - 1s 860us/step - loss: 0.4037 - accuracy: 0.8301
# Epoch 100/100
# 704/704 [==============================] - 1s 836us/step - loss: 0.4059 - accuracy: 0.8278

# %% [markdown]
# 9. Plot the loss function and accuracy.

# %%
# Create a DataFrame with the history dictionary


# Plot the loss

# %%
# Plot the accuracy

# %% [markdown]
# 10. Evaluate the model using testing data and the `evaluate` method.

# %%
# Evaluate the model fit with linear dummy data

# %% [markdown]
# ## Challenge
#
# For this challenge section, you have to figure out how the model you created could be modified to improve the accuracy.
#
# 1. Review the Keras documentation about activation functions, and decide if there is anyone that could be used instead of `sigmoid`.
#
# 2. Add a second hidden layer with `69` units and use a different activation function than `sigmoid`.
#
# 3. Change any other parameter that you believe could improve the model's accuracy.
#
# 4. Evaluate the model's accuracy and loss and write down your conclusions.

# %%
# Define the model

# %%
# Compile model

# %%
# Fit the model

# %%
# Evaluate the model fit with linear dummy data

# %% [markdown]
# ### Conclusions
#
# **Your Answer Here**
